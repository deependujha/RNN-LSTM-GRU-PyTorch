# %%
import torch
import torch.nn as nn

# %%
rnn = nn.RNN(input_size=10, hidden_size=20, num_layers=10, batch_first=True)
input = torch.randn(32,10, 10)
print(input.shape)
# Out:
# torch.Size([32, 10, 10])

# %%
h0 = torch.randn(10, 32, 20)
print(h0.shape)
# Out:
# torch.Size([10, 32, 20])

# %%
output, hn = rnn(input, h0)

# %%
output.shape, hn.shape
# Out:
# (torch.Size([32, 10, 20]), torch.Size([10, 32, 20]))

# %%
rnn.weight_hh
# Out:
# Parameter containing:
# tensor([[-3.3649e-02,  1.0500e-01, -1.6970e-01, -1.0040e-01,  1.8518e-01,
#           1.7649e-04, -8.8036e-02,  7.3554e-02, -1.5128e-01,  1.4126e-01,
#           2.6630e-02,  3.5534e-02,  5.7891e-02, -1.6932e-01, -5.3694e-02,
#          -2.0842e-01,  7.4746e-02,  1.3140e-01,  1.7346e-01, -2.2042e-01],
#         [ 1.1091e-01,  4.8689e-02, -2.3923e-02, -8.3427e-02,  1.6940e-01,
#          -1.4794e-01,  1.2253e-01,  2.2162e-01,  8.4603e-02,  5.5219e-02,
#           7.3572e-02,  1.3957e-01, -1.9601e-01, -9.0345e-02, -1.2336e-01,
#          -2.0512e-01, -3.8293e-02,  1.6441e-01,  4.5299e-02, -5.7059e-02],
#         [ 9.1717e-02,  9.7115e-02, -1.3153e-01, -1.2323e-01,  1.3107e-01,
#          -4.3169e-02,  1.6907e-01, -9.9627e-02, -1.7598e-01, -6.9932e-02,
#          -1.9552e-01, -2.3302e-02,  3.9757e-02,  2.1101e-01,  1.1210e-01,
#           1.5780e-01,  1.8537e-01,  2.3872e-02, -1.0587e-01,  1.2530e-01],
# ...
